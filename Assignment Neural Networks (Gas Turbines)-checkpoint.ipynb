# %% [markdown]
# The dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine.
# The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
#
#
# Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.

# %%
# Importig Libraries
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the data set
data = pd.read_csv("C:/Users/Admin/Desktop/Data Science/Assignment/gas_turbines(nn).csv")
data.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (15039, 11)

# %%
# Changing position of target column 'TEY'
Target = data['TEY']
#Drop the existing column
data.drop(labels=['TEY'], axis=1,inplace = True)
data.insert(0, 'Y', Target)

data = data.rename({'Y':'TEY'}, axis = 1)

data.head()
# Out:
#       TEY      AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP  \
# 0  114.70  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605
# 1  114.72  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598
# 2  114.71  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601
# 3  114.72  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606
# 4  114.72  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEY     15039 non-null  float64
#  1   AT      15039 non-null  float64
#  2   AP      15039 non-null  float64
#  3   AH      15039 non-null  float64
#  4   AFDP    15039 non-null  float64
#  5   GTEP    15039 non-null  float64
#  6   TIT     15039 non-null  float64
#  7   TAT     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                 TEY            AT           AP            AH          AFDP  \
# count  15039.000000  15039.000000  15039.00000  15039.000000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174      4.200294
# std       15.829717      7.574323      6.41076     13.793439      0.760197
# min      100.170000      0.522300    985.85000     30.344000      2.087400
# 25%      127.985000     11.408000   1008.90000     69.750000      3.723900
# 50%      133.780000     18.186000   1012.80000     82.266000      4.186200
# 75%      140.895000     23.862500   1016.90000     90.043500      4.550900
# max      174.610000     34.929000   1034.20000    100.200000      7.610600
#
#                GTEP           TIT           TAT           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean      25.419061   1083.798770    545.396183     12.102353      1.972499
# std        4.173916     16.527806      7.866803      1.103196      2.222206
# min       17.878000   1000.800000    512.450000      9.904400      0.000388
# 25%       23.294000   1079.600000    542.170000     11.622000      0.858055
# 50%       25.082000   1088.700000    549.890000     12.025000      1.390200
# 75%       27.184000   1096.000000    550.060000     12.578000      2.160400
# max       37.402000   1100.800000    550.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
data.isna().sum()
# Out:
# TEY     0
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
# Checking correlation between variables
data.corr()
# Out:
#            TEY        AT        AP        AH      AFDP      GTEP       TIT  \
# TEY   1.000000 -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587
# AT   -0.207495  1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067
# AP    0.146939 -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650
# AH   -0.110272 -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781
# AFDP  0.717995 -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254
# GTEP  0.977042 -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526
# TIT   0.891587  0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000
# TAT  -0.720356  0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320
# CDP   0.988473 -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238
# CO   -0.541751 -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272
# NOX  -0.102631 -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636
#
#            TAT       CDP        CO       NOX
# TEY  -0.720356  0.988473 -0.541751 -0.102631
# AT    0.338569 -0.100705 -0.088588 -0.600006
# AP   -0.223479  0.131198  0.041614  0.256744
# AH    0.010859 -0.182010  0.165505  0.143061
# AFDP -0.571541  0.727152 -0.334207 -0.037299
# GTEP -0.756884  0.993784 -0.508259 -0.208496
# TIT  -0.357320  0.887238 -0.688272 -0.231636
# TAT   1.000000 -0.744740  0.063404  0.009888
# CDP  -0.744740  1.000000 -0.520783 -0.169103
# CO    0.063404 -0.520783  1.000000  0.316743
# NOX   0.009888 -0.169103  0.316743  1.000000

# %%
# Heatmap of correlation matrix
corr = data.corr()
fig, ax = plt.subplots(figsize=(15, 8))
#Generate Heat Map, allow annotations and place floats in map
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt=".2f")
plt.xticks(range(len(corr.columns)), corr.columns);
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
# plot regplots  for Age, KM, HP, CC, Doors, Gears, Quarterly_Tax and Weight against TEY 
f, axes = plt.subplots(5,2, figsize=(15,20))

sns.regplot(x = 'TEY', y = 'AT', data = data, ax = axes[0,0], color = 'g', scatter_kws={'alpha':0.6})
axes[0,0].set_xlabel('TEY', fontsize = 14)
axes[0,0].set_ylabel('AT', fontsize=14)
axes[0,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AP', data = data, ax = axes[0,1], color = 'y',scatter_kws={'alpha':0.6})
axes[0,1].set_xlabel('TEY', fontsize = 14)
axes[0,1].set_ylabel('AP', fontsize=14)
axes[0,1].yaxis.set_label_position("right")
axes[0,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'AH', data = data, ax = axes[1,0], color = 'g',scatter_kws={'alpha':0.6})
axes[1,0].set_xlabel('TEY', fontsize = 14)
axes[1,0].set_ylabel('AH', fontsize=14)
axes[1,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AFDP', data = data, ax = axes[1,1], color = 'y',scatter_kws={'alpha':0.6})
axes[1,1].set_xlabel('TEY', fontsize = 14)
axes[1,1].set_ylabel('AFDP', fontsize=14)
axes[1,1].yaxis.set_label_position("right")
axes[1,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'GTEP', data = data, ax = axes[2,0], color = 'g',scatter_kws={'alpha':0.6})
axes[2,0].set_xlabel('TEY', fontsize = 14)
axes[2,0].set_ylabel('GTEP', fontsize=14)
axes[2,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'TIT', data = data, ax = axes[2,1], color = 'y',scatter_kws={'alpha':0.6})
axes[2,1].set_xlabel('TEY', fontsize = 14)
axes[2,1].set_ylabel('TIT', fontsize=14)
axes[2,1].yaxis.set_label_position("right")
axes[2,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'TAT', data = data, ax = axes[3,0], color = 'g',scatter_kws={'alpha':0.6})
axes[3,0].set_xlabel('TEY', fontsize = 14)
axes[3,0].set_ylabel('TAT', fontsize=14)
axes[3,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'CDP', data = data, ax = axes[3,1], color = 'y',scatter_kws={'alpha':0.6})
axes[3,1].set_xlabel('TEY', fontsize = 14)
axes[3,1].set_ylabel('CDP', fontsize=14)
axes[3,1].yaxis.set_label_position("right")
axes[3,1].yaxis.tick_right()

sns.regplot(x = 'TEY', y = 'CO', data = data, ax = axes[4,0], color = 'g',scatter_kws={'alpha':0.6})
axes[4,0].set_xlabel('TEY', fontsize = 14)
axes[4,0].set_ylabel('CO', fontsize=14)
axes[4,0].yaxis.set_label_position("right")
axes[4,0].yaxis.tick_left()

sns.regplot(x = 'TEY', y = 'NOX', data = data, ax = axes[4,1], color = 'y',scatter_kws={'alpha':0.6})
axes[4,1].set_xlabel('TEY', fontsize = 14)
axes[4,1].set_ylabel('NOX', fontsize=14)
axes[4,1].yaxis.set_label_position("right")
axes[4,1].yaxis.tick_right()

plt.show()

# %% [markdown]
# # Feature Selection by using Mutual Information Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %%
X = data.iloc[:,1:]
y = data.iloc[:,0]

# %%
# feature selection
def select_features(X_train, y_train, X_test):
    # configure to select all features
    fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    fs.fit(X_train, y_train)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    return X_train_fs, X_test_fs, fs

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# %%
# what are scores for the features
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.show()
# Out:
# Feature 0: 0.403517
# Feature 1: 0.143975
# Feature 2: 0.091371
# Feature 3: 0.656530
# Feature 4: 1.591459
# Feature 5: 1.305035
# Feature 6: 0.913794
# Feature 7: 1.709619
# Feature 8: 0.506960
# Feature 9: 0.303036

# %% [markdown]
# As per above feature selection method, we will select only features with good score to build our model

# %%
X = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]

# %%
y = data.iloc[:,0]

# %%
# Standardizing data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]

# %%
scaled_features=scaler.transform(X)
data_head=pd.DataFrame(scaled_features,columns=X.columns)
data_head
# Out:
#            AFDP      GTEP       TIT       TAT       CDP
# 0     -0.921232 -1.379101 -1.488376  0.585240 -1.357331
# 1     -0.921495 -1.363528 -1.482325  0.585240 -1.363676
# 2     -0.944385 -1.351309 -1.476275  0.568715 -1.360957
# 3     -0.946884 -1.348194 -1.464173  0.583969 -1.356424
# 4     -0.924389 -1.354663 -1.458123  0.582698 -1.350985
# ...         ...       ...       ...       ...       ...
# 15034 -0.865850 -1.498657 -2.063184  0.103453 -1.543161
# 15035 -0.913470 -1.438759 -2.268905 -0.276638 -1.513247
# 15036 -0.951488 -1.410967 -2.789257 -1.026650 -1.467922
# 15037 -0.988848 -1.447624 -2.456474 -0.528337 -1.422598
# 15038 -1.016605 -1.464635 -2.051083  0.057689 -1.377273
#
# [15039 rows x 5 columns]

# %%
# Splitting data into test data and train data

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('Shape of x_train: ', x_train.shape)
print('Shape of x_test: ', x_test.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of x_train:  (10527, 5)
# Shape of x_test:  (4512, 5)
# Shape of y_train:  (10527,)
# Shape of y_test:  (4512,)

# %% [markdown]
# # Artificial Neural Network Model - Backpropagation

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=5, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(6, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(1, kernel_initializer='he_uniform', activation='linear'))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
# Fit the model
model.fit(x_train,y_train, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 264/264 [==============================] - 1s 2ms/step - loss: 1.2071 - mse: 1.2071
# Epoch 2/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 3/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 4/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 5/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9950 - mse: 0.9950
# Epoch 6/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9947 - mse: 0.9947
# Epoch 7/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9943 - mse: 0.9943
# Epoch 8/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9946 - mse: 0.9946
# Epoch 9/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 10/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 11/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9950 - mse: 0.9950
# Epoch 12/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9942 - mse: 0.9942
# Epoch 13/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9956 - mse: 0.9956
# Epoch 14/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9944 - mse: 0.9944
# Epoch 15/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9954 - mse: 0.9954
# Epoch 16/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 17/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 18/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 19/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9944 - mse: 0.9944
# Epoch 20/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 21/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9945 - mse: 0.9945
# Epoch 22/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 23/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9944 - mse: 0.9944
# Epoch 24/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9949 - mse: 0.9949
# Epoch 25/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 26/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9948 - mse: 0.9948
# Epoch 27/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9944 - mse: 0.9944
# Epoch 28/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 29/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9946 - mse: 0.9946
# Epoch 30/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9954 - mse: 0.9954
# Epoch 31/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 32/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9950 - mse: 0.9950
# Epoch 33/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9945 - mse: 0.9945
# Epoch 34/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9946 - mse: 0.9946
# Epoch 35/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9943 - mse: 0.9943
# Epoch 36/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 37/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9945 - mse: 0.9945
# Epoch 38/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9942 - mse: 0.9942
# Epoch 39/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9942 - mse: 0.9942
# Epoch 40/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 41/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 42/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 43/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 44/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 45/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9943 - mse: 0.9943
# Epoch 46/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 47/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 48/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 49/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 50/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 51/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 52/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9932 - mse: 0.9932
# Epoch 53/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 54/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 55/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 56/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 57/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9939 - mse: 0.9939
# Epoch 58/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 59/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 60/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 61/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 62/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9930 - mse: 0.9930
# Epoch 63/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 64/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9939 - mse: 0.9939
# Epoch 65/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 66/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 67/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 68/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9929 - mse: 0.9929
# Epoch 69/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 70/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 71/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 72/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 73/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 74/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 75/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9940 - mse: 0.9940
# Epoch 76/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 77/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9931 - mse: 0.9931
# Epoch 78/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 79/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 80/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 81/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9929 - mse: 0.9929
# Epoch 82/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 83/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 84/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 85/100
# 264/264 [==============================] - 1s 2ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 86/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 87/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 88/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 89/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 90/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9938 - mse: 0.9938
# Epoch 91/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 92/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9931 - mse: 0.9931
# Epoch 93/100
# 264/264 [==============================] - 0s 2ms/step - loss: 0.9932 - mse: 0.9932
# Epoch 94/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9934 - mse: 0.9934
# Epoch 95/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9931 - mse: 0.9931
# Epoch 96/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 97/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9933 - mse: 0.9933
# Epoch 98/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 99/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9935 - mse: 0.9935
# Epoch 100/100
# 264/264 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937

# %%
# evaluate the model
scores = model.evaluate(x_test, y_test)
print((model.metrics_names[1]))
# Out:
# 141/141 [==============================] - 0s 1ms/step - loss: 1.0167 - mse: 1.0167
# mse

# %% [markdown]
# # Artificial Neural Network Model - Tuning of All Hyperparameters

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam_v2
from keras.layers import Dropout

# %%
X = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
y = data.iloc[:,0]

# %%
# Selecting first 500 records
X = X.iloc[0:500,:]

# %%
# Selecting first 500 records
y = y.iloc[0:500]

# %%
# Scaling all the features
scaler.fit(X)
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]

# %%
scaled_features=scaler.transform(X)
data_head=pd.DataFrame(scaled_features,columns=X.columns)
data_head
# Out:
#          AFDP      GTEP       TIT       TAT       CDP
# 0   -1.759902 -1.532845 -2.140879  0.597669 -1.637742
# 1   -1.760236 -1.516668 -2.132865  0.597669 -1.644533
# 2   -1.789273 -1.503977 -2.124851  0.584370 -1.641623
# 3   -1.792443 -1.500741 -2.108824  0.596646 -1.636771
# 4   -1.763907 -1.507461 -2.100811  0.595623 -1.630950
# ..        ...       ...       ...       ...       ...
# 495  0.427695  0.194256 -0.706435 -0.594154 -0.072722
# 496 -1.244251 -1.463412 -3.919909 -0.777275 -1.760964
# 497 -1.300155 -1.463661 -3.984018 -0.855025 -1.660057
# 498 -1.030481 -1.114010 -3.463131 -0.919476 -1.255462
# 499  0.972718  1.029685  1.144718 -0.334306  0.891710
#
# [500 rows x 5 columns]

# %%
# Splitting data into test data and train data

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('Shape of x_train: ', x_train.shape)
print('Shape of x_test: ', x_test.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of x_train:  (350, 5)
# Shape of x_test:  (150, 5)
# Shape of y_train:  (350,)
# Shape of y_test:  (150,)

# %%
from sklearn.metrics import mean_squared_error

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 5,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'linear'))
    
    adam=adam_v2.Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [20,40]
epochs = [50,100]
learning_rate = [0.01,0.1]
dropout_rate = [0.1,0.2]
activation_function = ['relu','linear']
init = ['uniform','normal']
neuron1 = [4,8]
neuron2 = [2,4]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10, scoring='neg_mean_squared_error')
grid_result = grid.fit(x_train, y_train)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10268/3105531578.py:15: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# [CV 1/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.513 total time=   1.4s
# [CV 2/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 6ms/step
# [CV 2/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 3/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.431 total time=   1.4s
# [CV 4/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.689 total time=   1.2s
# [CV 5/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000218EF7AD160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 5ms/step
# [CV 5/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.112 total time=   1.2s
# [CV 1/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000218F085D670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 6ms/step
# [CV 1/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.513 total time=   1.9s
# [CV 2/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.202 total time=   2.1s
# [CV 3/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 3ms/step
# [CV 3/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.431 total time=   1.9s
# [CV 4/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.689 total time=   1.8s
# [CV 5/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 5/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.112 total time=   1.8s
# [CV 1/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 1/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.513 total time=   1.8s
# [CV 2/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 2/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.202 total time=   1.8s
# [CV 3/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 3/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.431 total time=   1.9s
# [CV 4/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 4/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.689 total time=   1.8s
# [CV 5/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 5/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.112 total time=   2.6s
# [CV 1/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.513 total time=   2.3s
# [CV 2/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 2/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.202 total time=   2.0s
# [CV 3/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.431 total time=   1.7s
# [CV 4/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 4/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.689 total time=   1.8s
# [CV 5/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 5/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.112 total time=   1.3s
# [CV 1/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 3ms/step
# [CV 1/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.513 total time=   1.8s
# [CV 2/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 2/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.202 total time=   1.8s
# [CV 3/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 3/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.431 total time=   2.1s
# [CV 4/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 4/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.689 total time=   2.4s
# [CV 5/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 5/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.112 total time=   1.8s
# [CV 1/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 3ms/step
# [CV 1/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.513 total time=   1.5s
# [CV 2/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.202 total time=   1.2s
# [CV 3/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.431 total time=   1.3s
# [CV 4/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 4/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 9ms/step
# [CV 5/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.112 total time=   1.0s
# [CV 1/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.513 total time=   1.2s
# [CV 2/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 2/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.202 total time=   1.4s
# [CV 3/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 3/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.431 total time=   1.7s
# [CV 4/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.689 total time=   1.9s
# [CV 5/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.112 total time=   1.1s
# [CV 1/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 9ms/step
# [CV 1/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 2/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.202 total time=   1.2s
# [CV 3/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 6ms/step
# [CV 3/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.431 total time=   1.2s
# [CV 4/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 4/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.689 total time=   1.4s
# [CV 5/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 5/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.112 total time=   1.3s
# [CV 1/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 1ms/step
# [CV 1/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.513 total time=   1.5s
# [CV 2/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 2/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 3/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 4/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.689 total time=   1.5s
# [CV 5/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 5/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.112 total time=   1.5s
# [CV 1/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 2/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.202 total time=   1.4s
# [CV 3/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.431 total time=   1.2s
# [CV 4/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 4/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.689 total time=   1.2s
# [CV 5/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.112 total time=   1.5s
# [CV 1/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 1/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.513 total time=   1.2s
# [CV 2/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 2/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 3/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.689 total time=   1.3s
# [CV 5/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.112 total time=   1.3s
# [CV 1/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.513 total time=   1.7s
# [CV 2/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 6ms/step
# [CV 2/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.202 total time=   1.6s
# [CV 3/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 1ms/step
# [CV 3/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.431 total time=   1.3s
# [CV 4/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 4/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 3ms/step
# [CV 5/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.112 total time=   1.1s
# [CV 1/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.513 total time=   1.0s
# [CV 2/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 3ms/step
# [CV 3/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.689 total time=   1.0s
# [CV 5/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.112 total time=   1.0s
# [CV 1/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.513 total time=   1.0s
# [CV 2/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 7ms/step
# [CV 2/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.202 total time=   1.3s
# [CV 3/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 3/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.431 total time=   1.5s
# [CV 4/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.689 total time=   1.3s
# [CV 5/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.112 total time=   1.0s
# [CV 1/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 1/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.513 total time=   1.1s
# [CV 2/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 3/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.431 total time=   1.0s
# [CV 4/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.689 total time=   1.1s
# [CV 5/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.112 total time=   1.2s
# [CV 1/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 1/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.202 total time=   1.0s
# [CV 3/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.431 total time=   1.1s
# [CV 4/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 6ms/step
# [CV 4/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.112 total time=   1.1s
# [CV 1/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 1/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.513 total time=   2.4s
# [CV 2/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 2/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.202 total time=   1.8s
# [CV 3/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 3/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.431 total time=   1.9s
# [CV 4/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 4/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.689 total time=   1.7s
# [CV 5/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.112 total time=   1.7s
# [CV 1/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 6ms/step
# [CV 1/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.513 total time=   1.7s
# [CV 2/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 2/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.202 total time=   2.1s
# [CV 3/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 3/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.431 total time=   1.7s
# [CV 4/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.689 total time=   2.4s
# [CV 5/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.112 total time=   1.7s
# [CV 1/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.513 total time=   1.7s
# [CV 2/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 2/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.202 total time=   1.7s
# [CV 3/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 3/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.431 total time=   1.7s
# [CV 4/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.689 total time=   1.7s
# [CV 5/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 5/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.112 total time=   1.8s
# [CV 1/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.513 total time=   1.9s
# [CV 2/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.202 total time=   2.2s
# [CV 3/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 9ms/step
# [CV 3/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.431 total time=   2.0s
# [CV 4/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.689 total time=   1.9s
# [CV 5/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 5/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.112 total time=   1.9s
# [CV 1/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 1/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.513 total time=   1.9s
# [CV 2/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 2/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.202 total time=   1.8s
# [CV 3/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 3/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.431 total time=   1.8s
# [CV 4/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.689 total time=   1.8s
# [CV 5/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 5/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.112 total time=   2.4s
# [CV 1/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.513 total time=   1.9s
# [CV 2/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 3ms/step
# [CV 2/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.202 total time=   1.7s
# [CV 3/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.431 total time=   1.7s
# [CV 4/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 4/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.689 total time=   1.7s
# [CV 5/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 6ms/step
# [CV 5/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.112 total time=   1.7s
# [CV 1/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 1/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.513 total time=   1.7s
# [CV 2/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 7ms/step
# [CV 2/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.202 total time=   1.8s
# [CV 3/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.431 total time=   2.2s
# [CV 4/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 4/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.689 total time=   2.1s
# [CV 5/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 6ms/step
# [CV 5/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.112 total time=   2.0s
# [CV 1/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 1/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.513 total time=   1.7s
# [CV 2/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 7ms/step
# [CV 2/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.202 total time=   1.8s
# [CV 3/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 3/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.431 total time=   1.7s
# [CV 4/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.689 total time=   1.7s
# [CV 5/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 2ms/step
# [CV 5/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.112 total time=   1.8s
# [CV 1/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 5ms/step
# [CV 1/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.513 total time=   2.0s
# [CV 2/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 3ms/step
# [CV 2/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.202 total time=   2.1s
# [CV 3/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# ...
# [CV 5/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 9ms/step
# [CV 5/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.112 total time=   1.1s
# [CV 1/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 1/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.513 total time=   1.1s
# [CV 2/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-4.689 total time=   1.1s
# [CV 5/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 5/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2;, score=-5.112 total time=   1.1s
# [CV 1/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 1/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 2/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.202 total time=   1.1s
# [CV 3/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.431 total time=   1.1s
# [CV 4/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-4.689 total time=   1.3s
# [CV 5/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 4ms/step
# [CV 5/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4;, score=-5.112 total time=   1.6s
# [CV 1/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 1/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.513 total time=   1.2s
# [CV 2/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.202 total time=   1.4s
# [CV 3/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 4ms/step
# [CV 4/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-4.689 total time=   1.1s
# [CV 5/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2;, score=-5.112 total time=   1.3s
# [CV 1/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.513 total time=   1.3s
# [CV 2/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 7ms/step
# [CV 2/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.202 total time=   1.1s
# [CV 3/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.431 total time=   1.1s
# [CV 4/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4;, score=-5.112 total time=   1.1s
# [CV 1/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 1/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.513 total time=   1.2s
# [CV 2/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 9ms/step
# [CV 2/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.202 total time=   1.5s
# [CV 3/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 3/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.431 total time=   1.2s
# [CV 4/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-4.689 total time=   1.1s
# [CV 5/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 5/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2;, score=-5.112 total time=   1.1s
# [CV 1/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 2/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.202 total time=   1.1s
# [CV 3/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.431 total time=   1.1s
# [CV 4/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# 3/3 [==============================] - 0s 5ms/step
# [CV 5/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4;, score=-5.112 total time=   1.3s
# [CV 1/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 1/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.513 total time=   1.1s
# [CV 2/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 2/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.202 total time=   1.1s
# [CV 3/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 2ms/step
# [CV 3/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.431 total time=   1.1s
# [CV 4/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-4.689 total time=   1.4s
# [CV 5/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# 3/3 [==============================] - 0s 8ms/step
# [CV 5/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2;, score=-5.112 total time=   1.5s
# [CV 1/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 1/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.513 total time=   1.1s
# [CV 2/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 3ms/step
# [CV 2/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.202 total time=   1.1s
# [CV 3/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 3/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.431 total time=   1.1s
# [CV 4/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 0s/step
# [CV 4/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-4.689 total time=   1.1s
# [CV 5/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# 3/3 [==============================] - 0s 8ms/step
# [CV 5/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4;, score=-5.112 total time=   1.1s
# Best : -4.989548995284916, using {'activation_function': 'relu', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}

# %%
# create model
final_model = Sequential()
final_model.add(Dense(4,input_dim = 5,kernel_initializer = 'uniform',activation = 'relu'))
final_model.add(Dropout(0.1))
final_model.add(Dense(2,input_dim = 4,kernel_initializer = 'uniform',activation = 'relu'))
final_model.add(Dropout(0.1))
final_model.add(Dense(1,activation = 'linear'))
    
adam=adam_v2.Adam(learning_rate = 0.01)

# %%
# Compile Model
final_model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])

# %%
# Fit the model
final_model.fit(x_train,y_train, epochs=50, batch_size=20)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3742 - mse: 1.3742
# Epoch 2/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0053 - mse: 1.0053
# Epoch 3/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0024 - mse: 1.0024
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0007 - mse: 1.0007
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9996 - mse: 0.9996
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 7/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9994 - mse: 0.9994
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0006 - mse: 1.0006
# Epoch 9/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9994 - mse: 0.9994
# Epoch 10/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 11/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9993 - mse: 0.9993
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9995 - mse: 0.9995
# Epoch 13/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 14/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 15/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 16/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9991 - mse: 0.9991
# Epoch 17/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0003 - mse: 1.0003
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0005 - mse: 1.0005
# Epoch 19/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0006 - mse: 1.0006
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 21/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0008 - mse: 1.0008
# Epoch 22/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9995 - mse: 0.9995
# Epoch 23/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9997 - mse: 0.9997
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9996 - mse: 0.9996
# Epoch 25/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 26/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9992 - mse: 0.9992
# Epoch 27/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0009 - mse: 1.0009
# Epoch 28/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0008 - mse: 1.0008
# Epoch 29/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9997 - mse: 0.9997
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9998 - mse: 0.9998
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9995 - mse: 0.9995
# Epoch 32/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0021 - mse: 1.0021
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9991 - mse: 0.9991
# Epoch 34/50
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 35/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9997 - mse: 0.9997
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0008 - mse: 1.0008
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0005 - mse: 1.0005
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 39/50
# 18/18 [==============================] - 0s 3ms/step - loss: 1.0016 - mse: 1.0016
# Epoch 40/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0027 - mse: 1.0027
# Epoch 41/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9994 - mse: 0.9994
# Epoch 42/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 44/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.9993 - mse: 0.9993
# Epoch 45/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9992 - mse: 0.9992
# Epoch 46/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9995 - mse: 0.9995
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.9993 - mse: 0.9993
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.9995 - mse: 0.9995
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9995 - mse: 0.9995

# %%
scores = final_model.evaluate(x_test, y_test)
print((final_model.metrics_names[1]))
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0054 - mse: 1.0054
# mse
